# %%
import streamlit as st
from PIL import Image
import pandas as pd
import numpy as np
import os

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

import string

# %%
def ing_list2(sample_txt):
    elements = []
    for punc in string.punctuation:
        sample_txt = sample_txt.replace(punc,'')
    for word in sample_txt.split():
        elements.append(str(word))
    return elements

# %%
processed_df = pd.read_csv('../replenish_streamlit/raw_data/model_df_final.csv')

# %%
processed_df
# Out:
#                              recipe_title     combined      dietary stars  \
# 0                         'Panforte' pies            n            n   4.7
# 1                10-minute couscous salad   vegetarian   vegetarian   4.7
# 2                      10-minute pad Thai            n            n   3.9
# 3      10-minute steak & blue cheese wrap            n            n     3
# 4         10-minute steak & noodle supper            n            n     3
# ...                                   ...          ...          ...   ...
# 10668     Zingy salmon & brown rice salad      healthy      healthy     4
# 10669                      Zombie fingers            n            n     4
# 10670     Zoolbia (lacy saffron fritters)   vegetarian   vegetarian     n
# 10671   ‘Butter pie’ with apples & cheese   vegetarian   vegetarian     4
# 10672                        ‘Doved’ peas  gluten-free  gluten-free     4
#
#       prep_times cooking_times review_count difficulty_level         servings  \
# ...

# %%
model_df=processed_df.copy().reset_index(drop=True)
word_cloud_index = model_df[model_df.recipe_title == '10-minute tortellini'].index.tolist()[0]
clus = model_df['cluster'][word_cloud_index]
st.write(model_df)
model_df['final_ingredients'] = model_df['final_ingredients'].apply(ing_list2)

list_of_ing = model_df.groupby('cluster')['final_ingredients'].sum()[clus]

st.write(list_of_ing)

string_of_ing = ', '.join(list_of_ing)

# path = os.path.join(os.getcwd(), 'raw_data')
# font_path_ = os.path.join(path, 'Helvetica.ttc')

wordcloud = WordCloud().generate(string_of_ing)
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.gcf().set_facecolor("white")
plt.axis("off")
plt.show()

# %%
processed_df
# Out:
#                              recipe_title     combined      dietary stars  \
# 0                         'Panforte' pies            n            n   4.7
# 1                10-minute couscous salad   vegetarian   vegetarian   4.7
# 2                      10-minute pad Thai            n            n   3.9
# 3      10-minute steak & blue cheese wrap            n            n     3
# 4         10-minute steak & noodle supper            n            n     3
# ...                                   ...          ...          ...   ...
# 10668     Zingy salmon & brown rice salad      healthy      healthy     4
# 10669                      Zombie fingers            n            n     4
# 10670     Zoolbia (lacy saffron fritters)   vegetarian   vegetarian     n
# 10671   ‘Butter pie’ with apples & cheese   vegetarian   vegetarian     4
# 10672                        ‘Doved’ peas  gluten-free  gluten-free     4
#
#       prep_times cooking_times review_count difficulty_level         servings  \
# ...

# %%
df = processed_df[['clean_text']]

# %%
df
# Out:
#                                               clean_text
# 0      sugar syrup butter egg cream chocolate cinnamo...
# 1         cheese pesto pepper feta onion spring couscous
# 2            sugar egg sauce lime prawn beansprouts fish
# 3            oil rocket pepper olive steak onion stilton
# 4                          pak oil choi pepper sunflower
# ...                                                  ...
# 10668  basmati chilli soya sauce lime salmon soy bean...
# 10669                     almond chocolate peanut butter
# 10670                                        sugar flour
# 10671     cox butter egg apple flour thyme cabbage onion
# 10672     garlic butter bacon cleave thyme lardons onion
#
# [9045 rows x 1 columns]

# %%
stre = 'sugar water orange chocolate flour'

# %%
df.tail(10)
# Out:
#                                               clean_text
# 10663  sugar carrot oil garlic clove pepper chestnut ...
# 10664                   sugar egg cinnamon almond ginger
# 10665           chilli oil lemon olive spinach courgette
# 10666                 oil honey olive caper onion potato
# 10667              watercress salmon orange radish onion
# 10668  basmati chilli soya sauce lime salmon soy bean...
# 10669                     almond chocolate peanut butter
# 10670                                        sugar flour
# 10671     cox butter egg apple flour thyme cabbage onion
# 10672     garlic butter bacon cleave thyme lardons onion
